# %%
#python basic imports
import math
import multiprocessing
#3rd party imports (from packages, the environment)
import numpy as np
#custom (local) imports
import experiment.config as config
from util.database import Database
from util.logging import setupLogging, shutdownLogging
from IPython.display import clear_output, display, HTML
from util.worker import worker
from experiment.optimizers import MonteCarloSampling1M
import experiment.optimizers as optimizers

# %%
#Experimental Setup

if __name__ == '__main__':
    logger = setupLogging()
    logger.info("Evaluation "+str(config.EVALUATION_HASH))
    db = Database()
    db.loadFromJson(config.DATABASE_PATH)
# Out:
# Start Logging
# Evaluation 82909850012955443557adc2a05682e2ddd74e9e1421ea30ec2819dac6f9eb24

# %%
if __name__ == '__main__':
    maxScoresDict = dict()
    bestAvgScoresDict = Database()
    sumOfScoresDict = dict()
    noOfScoresDict = dict()
    meanOfScoresDict = dict()
    targetValuesDict = dict()
    
    for optimizerId,optimizerValues in db.core.items():
        for problemId,problemValues in optimizerValues.items():
            for k,values in problemValues.items():
                #logger.info(values.items())
                score = values['bestscore']
                #if ( (k == '1') and (optimizerId == 'GradOpt') ):
                    #logger.info(optimizerId + problemId + " k:"+k)
                    #logger.info(values['bestscore'])
                    #logger.info(values['bestparams'])

                
                if problemId in maxScoresDict:
                    if score > maxScoresDict[problemId]:
                        maxScoresDict[problemId] = score
                else:
                    maxScoresDict[problemId] = score
                
                #we calculate the mean only from the MonteCarloSampling1M optimizer.
                if ( optimizerId == MonteCarloSampling1M.__name__ ):
                    allScores = values['scores']
                    noOfScores = np.shape(allScores)[0]
                    sumOfScores = np.sum(allScores)
                    
                    #because we do this for each k:
                    if problemId in sumOfScoresDict:
                        sumOfScores += sumOfScoresDict[problemId]
                        noOfScores += noOfScoresDict[problemId]
                    
                    sumOfScoresDict[problemId] = sumOfScores
                    noOfScoresDict[problemId] = noOfScores

    #note: we only go over problems where we can calculate the mean values of f(x), e.g. where the monte carlo sampling exists.                
    if ( len(sumOfScoresDict.keys()) == 0):
        logger.info("No MonteCarloSampling exists, that can happen if you use an incomplete result.json file. Don't panic, just run the Benchmark further to fix this issue")
    for problemId in sumOfScoresDict.keys():
        mx = maxScoresDict[problemId]
        sm = sumOfScoresDict[problemId]
        mean = sm / noOfScoresDict[problemId]
        
        def target(t):
            return mx - ( ( mx - mean ) * (1-t) ) 
        targetValues = np.array([ target(t) for t in config.TARGETS ])
        
        logger.info("mx: "+str(mx))
        logger.info("mean: "+str(mean))    
        logger.info("target values of "+str(problemId)+" are: "+str(targetValues))
        targetValuesDict[problemId] = targetValues
    
    
    refinedResults = Database()
    for optimizerId,optimizerValues in db.core.items():
        #dont take the dummy optimizer MonteCarloSampling1M into the final evaluation
        if ( optimizerId == MonteCarloSampling1M.__name__ ):
            continue
        for problemId in sumOfScoresDict.keys():
            if not(problemId in optimizerValues.keys()):
                continue
            problemValues = optimizerValues[problemId]
            indexesWhereTargetValuesWhereExceeded = np.zeros((config.K,len(config.TARGETS)))
            logger.info(optimizerId+" on "+problemId)
            valueCounter = 0#only for debugging / validation
            completionCounter = 0 #count how many runs actually have config.MAX_EVALUATIONS values in them
            for k,values in problemValues.items():
                allScores = values['scores']
                valueCounter += np.shape(allScores)[0]
                completionCounter += int( np.shape(allScores)[0] >= config.MAX_EVALUATIONS )
                #check, at which index the values are above the target values
                mask = np.expand_dims( np.array(allScores), axis=-1) > np.expand_dims(targetValuesDict[problemId],axis=-1).T
                indexWhereTargetValuesAreHit = np.argmax(mask, axis=0)
                #if the algorithm never reached the target value, it is set to the maximum number of iterations:
                indexWhereTargetValuesAreHit[ np.diag( mask[indexWhereTargetValuesAreHit] ) == False ] = config.MAX_EVALUATIONS-1#since we count from index 0
                indexesWhereTargetValuesWhereExceeded[int(k),:] = indexWhereTargetValuesAreHit
            
            meanValue = np.mean(indexesWhereTargetValuesWhereExceeded, axis=0) + 1 #(since we count from index 0)
            stdValue = np.std(indexesWhereTargetValuesWhereExceeded, axis=0)
            
            refinedResults.store(optimizerId, problemId, 'mean', meanValue)
            refinedResults.store(optimizerId, problemId, 'std', stdValue)   
            logger.info("mean: "+str( meanValue ) )
            logger.info("std: "+str( stdValue ) )
            logger.info("completed runs: "+str(100.0*completionCounter/config.K)+"%")
            logger.info("completed function calls: "+str(100.0*valueCounter/(config.K*config.MAX_EVALUATIONS))+"%")
            
    
    #Determine, which optimizer was the best on on a problem in order to plot it thick
    for optimizerId,optimizerValues in refinedResults.core.items():
        for problemId,problemValues in optimizerValues.items():
            meanValues = problemValues['mean'].copy()
            if  bestAvgScoresDict.exists(problemId):
                oldValues = bestAvgScoresDict.get(problemId, 'values')
                oldBestOptimizerIds = bestAvgScoresDict.get(problemId, 'optimizerId')
                mask = ( meanValues < oldValues )
                maskEqual = ( meanValues == oldValues )
                oldValues[mask] = meanValues[mask]
                
                for i in range(np.shape(meanValues)[0]):
                    if mask[i]: oldBestOptimizerIds[i] = list([optimizerId])
                    if maskEqual[i]: oldBestOptimizerIds[i].append(optimizerId)

                bestAvgScoresDict.store(problemId, 'values', oldValues)
                bestAvgScoresDict.store(problemId, 'optimizerId', oldBestOptimizerIds)
            else:
                bestAvgScoresDict.store(problemId, 'values', meanValues)
                bestAvgScoresDict.store(problemId, 'optimizerId',[list([optimizerId]) for i in range(np.shape(meanValues)[0])])


def applyFilter(currentId, filterDict):
    if filterDict == None:
        return False
    if currentId in filterDict:
        return False
    return True
# Out:
# mx: -14.023527856747103
# mean: -14.575129778839946
# target values of Slump are: [-14.07868805 -14.05110795 -14.02904388]
# mx: 0.09896543115652726
# mean: -0.43568491983450164
# target values of BreastCancer are: [0.0455004  0.07223291 0.09361893]
# mx: 0.8849536315791152
# mean: -0.1144000329123871
# target values of Yacht are: [0.78501827 0.83498595 0.87496009]
# mx: 0.998830589570028
# mean: 0.12391307617569552
# target values of YachtHD are: [0.91133884 0.95508471 0.99008141]
# mx: -9.394761123171241
# mean: -12.264340349767382
# target values of SlumpHD are: [-9.68171905 -9.53824008 -9.42345692]
# mx: 0.14304370708515907
# mean: -0.45463565630672953
# target values of BreastCancerHD are: [0.08327577 0.11315974 0.13706691]
# mx: -10.683388833697906
# mean: -16.169047113491903
# target values of AutoMPG are: [-11.23195466 -10.95767175 -10.73824542]
# mx: -1.214749793197588
# mean: -6.167550156737873
# target values of HousingHD are: [-1.71002983 -1.46238981 -1.2642778 ]
# mx: -11.295189432095514
# mean: -17.265616496150315
# target values of Housing are: [-11.89223214 -11.59371079 -11.3548937 ]
# mx: -5.340408804663871
# mean: -9.35788598306744
# target values of AutoMPGHD are: [-5.74215652 -5.54128266 -5.38058358]
# AdaLipoTR on Slump
# mean: [8.5 8.5 9. ]
# std: [1.5 1.5 2. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on BreastCancer
# mean: [8. 8. 9.]
# std: [3. 3. 4.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on Yacht
# mean: [5. 5. 7.]
# std: [1. 1. 1.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on YachtHD
# mean: [ 5.  5. 34.]
# std: [ 3.  3. 32.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on SlumpHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on BreastCancerHD
# mean: [ 51.5  87.5 100. ]
# std: [48.5 12.5  0. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on AutoMPG
# mean: [5. 5. 5.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on HousingHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on Housing
# mean: [4.5 6.  6. ]
# std: [0.5 1.  1. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipoTR on AutoMPGHD
# mean: [99. 99. 99.]
# std: [1. 1. 1.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on Slump
# mean: [ 8.5 10.  10. ]
# std: [4.5 6.  6. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on BreastCancer
# mean: [18.  34.5 53.5]
# std: [12.  28.5 46.5]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on Yacht
# mean: [13. 13. 18.]
# std: [9. 9. 4.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on YachtHD
# mean: [ 4.   5.5 44. ]
# std: [ 1.   0.5 14. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on SlumpHD
# mean: [ 68.5  73.  100. ]
# std: [22.5 27.   0. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on BreastCancerHD
# mean: [62.5 62.5 62.5]
# std: [37.5 37.5 37.5]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on AutoMPG
# mean: [ 7.5 16.5 28.5]
# std: [2.5 3.5 8.5]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on HousingHD
# mean: [ 38.  38. 100.]
# std: [32. 32.  0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on Housing
# mean: [ 8.  19.5 50. ]
# std: [2.  9.5 3. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# AdaLipo on AutoMPGHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on Slump
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on BreastCancer
# mean: [23.5 23.5 36.5]
# std: [16.5 16.5  3.5]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on Yacht
# mean: [ 7.  31.5 43. ]
# std: [ 2.  26.5 15. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on YachtHD
# mean: [16.  46.  80.5]
# std: [ 8.  22.  19.5]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on SlumpHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on BreastCancerHD
# mean: [ 57.5 100.  100. ]
# std: [42.5  0.   0. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on AutoMPG
# mean: [ 53. 100. 100.]
# std: [47.  0.  0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on HousingHD
# mean: [ 59.  59. 100.]
# std: [41. 41.  0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on Housing
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# PureRandomSearch on AutoMPGHD
# mean: [ 39. 100. 100.]
# std: [34.  0.  0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on Slump
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on BreastCancer
# mean: [19.5 39.  39. ]
# std: [4.5 8.  8. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on Yacht
# mean: [ 7.5  7.5 73. ]
# std: [0.5 0.5 0. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on YachtHD
# mean: [  2. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on SlumpHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on BreastCancerHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on AutoMPG
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on HousingHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on Housing
# mean: [ 92.5 100.  100. ]
# std: [7.5 0.  0. ]
# completed runs: 100.0%
# completed function calls: 100.0%
# HierarchicalOptimisticOptimization on AutoMPGHD
# mean: [100. 100. 100.]
# std: [0. 0. 0.]
# completed runs: 100.0%
# completed function calls: 100.0%
# GradOpt on Slump
# mean: [ 7.   7.  10.5]
# std: [5.  5.  1.5]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on BreastCancer
# mean: [28. 56. 86.]
# std: [12. 16. 14.]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on Yacht
# mean: [ 6.5  6.5 24.5]
# std: [ 2.5  2.5 20.5]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on YachtHD
# mean: [ 54.5  54.5 100. ]
# std: [45.5 45.5  0. ]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on SlumpHD
# mean: [ 60.  97. 100.]
# std: [40.  3.  0.]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on BreastCancerHD
# mean: [ 28. 100. 100.]
# std: [19.  0.  0.]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on AutoMPG
# mean: [14. 14. 14.]
# std: [8. 8. 8.]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on HousingHD
# mean: [ 43.  47. 100.]
# std: [12. 10.  0.]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on Housing
# mean: [4. 4. 4.]
# std: [2. 2. 2.]
# completed runs: 0.0%
# completed function calls: 99.0%
# GradOpt on AutoMPGHD
# mean: [ 49.   64.5 100. ]
# std: [38.  35.5  0. ]
# completed runs: 0.0%
# completed function calls: 99.0%

# %%
#Render as html table
def createHTMLResultTable(tableString, index, problemFilter = None, optimizerFilter = None):
    tableString += '<table>'
    tableString += '    <tr>'
    tableString += '    <td>'+str(int(config.TARGETS[index]*100))+'% Target</td>'

    for problemId in maxScoresDict.keys():
        if ( applyFilter(problemId, problemFilter ) ): continue
        tableString += '<td>'+problemId+'</td>'

    for optimizerId,optimizerValues in refinedResults.core.items():
        if ( applyFilter(optimizerId, optimizerFilter ) ): continue
        tableString += '<tr>'
        tableString += '<td>'+optimizerId+'</td>'

        for problemId,problemValues in optimizerValues.items():
            if ( applyFilter(problemId, problemFilter ) ): continue

            isBestInCategory = ( optimizerId in (bestAvgScoresDict.get(problemId, 'optimizerId')[index]) )
            bestStartTag = ''
            bestEndTag = ''
            if ( isBestInCategory ):
                bestStartTag = '<b>'
                bestEndTag = '</b>'
                
            tableString += '<td>' + bestStartTag + str(problemValues['mean'][index]) + bestEndTag + '(+-' +str(("%.2f" % problemValues['std'][index]))+')' + '</td>'
    tableString += '</table>'
    return tableString

def renderHTMLTables(problemFilter = None, optimizerFilter = None):
    tableString = ""
    #Create one table per target setting
    for i in range(len(config.TARGETS)):
        tableString = createHTMLResultTable(tableString, i, problemFilter, optimizerFilter)
    display(HTML(tableString))
    
allProblems = [cls.__name__ for cls in config.problems.ALL.values()]
#optimizerFilter = [optimizers.PureRandomSearch.__name__, optimizers.BayesianOptimization.__name__, optimizers.HierarchicalOptimisticOptimization.__name__, optimizers.GradOpt.__name__]
print(allProblems)
renderHTMLTables(problemFilter = allProblems)
# Out:
# ['AutoMPGHD', 'BreastCancerHD', 'SlumpHD', 'YachtHD', 'HousingHD', 'AutoMPG', 'BreastCancer', 'Slump', 'Yacht', 'Housing', 'HolderTable', 'Rosenbrock', 'Sphere', 'SphereHighDim', 'LinearSlope', 'DebN1', 'BraninHoo', 'Himmelblau', 'Styblinski', 'LevyN13', 'MishraN2', 'GriewankN4', 'TestProblem', 'TestProblem2']
# <table>    <tr>    <td>90% Target</td><td>Slump</td><td>Yacht</td><td>BreastCancer</td><td>YachtHD</td><td>AutoMPG</td><td>SlumpHD</td><td>BreastCancerHD</td><td>Housing</td><td>HousingHD</td><td>AutoMPGHD</td><tr><td>AdaLipoTR</td><td>8.5(+-1.50)</td><td><b>8.0</b>(+-3.00)</td><td><b>5.0</b>(+-1.00)</td><td>5.0(+-3.00)</td><td>100.0(+-0.00)</td><td>51.5(+-48.50)</td><td><b>5.0</b>(+-0.00)</td><td>100.0(+-0.00)</td><td>4.5(+-0.50)</td><td>99.0(+-1.00)</td><tr><td>AdaLipo</td><td>8.5(+-4.50)</td><td>18.0(+-12.00)</td><td>13.0(+-9.00)</td><td>4.0(+-1.00)</td><td>68.5(+-22.50)</td><td>62.5(+-37.50)</td><td>7.5(+-2.50)</td><td><b>38.0</b>(+-32.00)</td><td>8.0(+-2.00)</td><td>100.0(+-0.00)</td><tr><td>PureRandomSearch</td><td>100.0(+-0.00)</td><td>23.5(+-16.50)</td><td>7.0(+-2.00)</td><td>16.0(+-8.00)</td><td>100.0(+-0.00)</td><td>57.5(+-42.50)</td><td>53.0(+-47.00)</td><td>59.0(+-41.00)</td><td>100.0(+-0.00)</td><td><b>39.0</b>(+-34.00)</td><tr><td>HierarchicalOptimisticOptimization</td><td>100.0(+-0.00)</td><td>19.5(+-4.50)</td><td>7.5(+-0.50)</td><td><b>2.0</b>(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>92.5(+-7.50)</td><td>100.0(+-0.00)</td><tr><td>GradOpt</td><td><b>7.0</b>(+-5.00)</td><td>28.0(+-12.00)</td><td>6.5(+-2.50)</td><td>54.5(+-45.50)</td><td><b>60.0</b>(+-40.00)</td><td><b>28.0</b>(+-19.00)</td><td>14.0(+-8.00)</td><td>43.0(+-12.00)</td><td><b>4.0</b>(+-2.00)</td><td>49.0(+-38.00)</td></table><table>    <tr>    <td>95% Target</td><td>Slump</td><td>Yacht</td><td>BreastCancer</td><td>YachtHD</td><td>AutoMPG</td><td>SlumpHD</td><td>BreastCancerHD</td><td>Housing</td><td>HousingHD</td><td>AutoMPGHD</td><tr><td>AdaLipoTR</td><td>8.5(+-1.50)</td><td><b>8.0</b>(+-3.00)</td><td><b>5.0</b>(+-1.00)</td><td><b>5.0</b>(+-3.00)</td><td>100.0(+-0.00)</td><td>87.5(+-12.50)</td><td><b>5.0</b>(+-0.00)</td><td>100.0(+-0.00)</td><td>6.0(+-1.00)</td><td>99.0(+-1.00)</td><tr><td>AdaLipo</td><td>10.0(+-6.00)</td><td>34.5(+-28.50)</td><td>13.0(+-9.00)</td><td>5.5(+-0.50)</td><td><b>73.0</b>(+-27.00)</td><td><b>62.5</b>(+-37.50)</td><td>16.5(+-3.50)</td><td><b>38.0</b>(+-32.00)</td><td>19.5(+-9.50)</td><td>100.0(+-0.00)</td><tr><td>PureRandomSearch</td><td>100.0(+-0.00)</td><td>23.5(+-16.50)</td><td>31.5(+-26.50)</td><td>46.0(+-22.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>59.0(+-41.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><tr><td>HierarchicalOptimisticOptimization</td><td>100.0(+-0.00)</td><td>39.0(+-8.00)</td><td>7.5(+-0.50)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><tr><td>GradOpt</td><td><b>7.0</b>(+-5.00)</td><td>56.0(+-16.00)</td><td>6.5(+-2.50)</td><td>54.5(+-45.50)</td><td>97.0(+-3.00)</td><td>100.0(+-0.00)</td><td>14.0(+-8.00)</td><td>47.0(+-10.00)</td><td><b>4.0</b>(+-2.00)</td><td><b>64.5</b>(+-35.50)</td></table><table>    <tr>    <td>99% Target</td><td>Slump</td><td>Yacht</td><td>BreastCancer</td><td>YachtHD</td><td>AutoMPG</td><td>SlumpHD</td><td>BreastCancerHD</td><td>Housing</td><td>HousingHD</td><td>AutoMPGHD</td><tr><td>AdaLipoTR</td><td><b>9.0</b>(+-2.00)</td><td><b>9.0</b>(+-4.00)</td><td><b>7.0</b>(+-1.00)</td><td><b>34.0</b>(+-32.00)</td><td><b>100.0</b>(+-0.00)</td><td>100.0(+-0.00)</td><td><b>5.0</b>(+-0.00)</td><td><b>100.0</b>(+-0.00)</td><td>6.0(+-1.00)</td><td><b>99.0</b>(+-1.00)</td><tr><td>AdaLipo</td><td>10.0(+-6.00)</td><td>53.5(+-46.50)</td><td>18.0(+-4.00)</td><td>44.0(+-14.00)</td><td><b>100.0</b>(+-0.00)</td><td><b>62.5</b>(+-37.50)</td><td>28.5(+-8.50)</td><td><b>100.0</b>(+-0.00)</td><td>50.0(+-3.00)</td><td>100.0(+-0.00)</td><tr><td>PureRandomSearch</td><td>100.0(+-0.00)</td><td>36.5(+-3.50)</td><td>43.0(+-15.00)</td><td>80.5(+-19.50)</td><td><b>100.0</b>(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td><td><b>100.0</b>(+-0.00)</td><td>100.0(+-0.00)</td><td>100.0(+-0.00)</td> ...

# %%
if __name__ == '__main__':
    shutdownLogging()
# Out:
# Shutdown logger, bye bye!
